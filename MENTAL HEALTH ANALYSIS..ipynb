# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Admin\Desktop\crude suicide rates.csv")
df.rename(columns={'Unnamed: 0':'Country', 'Unnamed: 1':'Year', 'Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease':'Pr of death Both', 'Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease.1': 'Prob of death Male', 'Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease.2':'Pr of death Female', 'Crude suicide rates (per 100 000 population)':'Crude scd Both', 'Crude suicide rates (per 100 000 population).1':'Crude scd Male', 'Crude suicide rates (per 100 000 population).2':'Crude scd Female'}, inplace=True)

# %%
df.drop(index=0, inplace=True)
df
# Out:
#          Country  Year Pr of death Both Prob of death Male Pr of death Female  \
# 1    Afghanistan  2016             29.8               31.8               27.7
# 2    Afghanistan  2015             29.8               31.9               27.8
# 3    Afghanistan  2010             31.7               34.1               29.4
# 4    Afghanistan  2005             34.1               36.5               31.6
# 5    Afghanistan  2000             34.4               36.6               32.1
# ..           ...   ...              ...                ...                ...
# 911     Zimbabwe  2016             19.3               18.7               19.8
# 912     Zimbabwe  2015             19.4               18.6               19.9
# 913     Zimbabwe  2010             21.1               20.5               21.5
# 914     Zimbabwe  2005             22.5               22.1               22.9
# 915     Zimbabwe  2000             21.6               21.6               21.7
#
# ...

# %%
#df['Prob of death Male'].mean()
df['Pr of death Female'].mean()
# Out:
# 17.639781420765026

# %%
#sns.barplot(x='Year', y='Pr of death Both', data=df)
df[['Pr of death Both', 'Prob of death Male', 'Pr of death Female', 'Crude scd Both', 'Crude scd Male', 'Crude scd Female']] = df[['Pr of death Both', 'Prob of death Male', 'Pr of death Female', 'Crude scd Both', 'Crude scd Male', 'Crude scd Female']].apply(pd.to_numeric)
sns.barplot(x='Year', y='Pr of death Both', data=df)
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Pr of death Both'>

# %%
sns.barplot(x='Year', y='Crude scd Both', data=df)
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Crude scd Both'>

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,5))

# Plot the first barplot on the left subplot
ax[0].bar(, data1, width=bar_width)
ax[0].set_xlabel('X Label 1')
ax[0].set_ylabel('Y Label 1')
ax[0].set_title('Title 1')

# Plot the second barplot on the right subplot
ax[1].bar(labels, data2, width=bar_width)
ax[1].set_xlabel('X Label 2')
ax[1].set_ylabel('Y Label 2')
ax[1].set_title('Title 2')

# Set the x-axis limits to fit both barplots
plt.xlim(-bar_width,len(labels)-bar_width)

# Add a legend to the plots
plt.legend(['Plot 1', 'Plot 2'])

# Display the plots
plt.show()

# %%
df
# Out:
#          Country  Year Pr of death Both Prob of death Male Pr of death Female  \
# 1    Afghanistan  2016             29.8               31.8               27.7
# 2    Afghanistan  2015             29.8               31.9               27.8
# 3    Afghanistan  2010             31.7               34.1               29.4
# 4    Afghanistan  2005             34.1               36.5               31.6
# 5    Afghanistan  2000             34.4               36.6               32.1
# ..           ...   ...              ...                ...                ...
# 911     Zimbabwe  2016             19.3               18.7               19.8
# 912     Zimbabwe  2015             19.4               18.6               19.9
# 913     Zimbabwe  2010             21.1               20.5               21.5
# 914     Zimbabwe  2005             22.5               22.1               22.9
# 915     Zimbabwe  2000             21.6               21.6               21.7
#
# ...

# %%
value_counts = df.Country.value_counts(dropna=False, normalize=False).reset_index()
value_counts.columns = ['value', 'count']
print(value_counts)
# Out:
#            value  count
# 0    Afghanistan      5
# 1    Netherlands      5
# 2      Nicaragua      5
# 3          Niger      5
# 4        Nigeria      5
# ..           ...    ...
# 178      Germany      5
# 179        Ghana      5
# 180       Greece      5
# 181      Grenada      5
# 182     Zimbabwe      5
#
# [183 rows x 2 columns]

# %%
data = df[df['Country'] == 'Nigeria']
data

data.plot(kind='bar', x='Year', y =['Crude scd Male', 'Crude scd Female'])
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
df2 = pd.read_csv(r"C:\Users\Admin\Desktop\share-with-alcohol-and-substance-use-disorders 1990-2016.csv")
df2
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6151     Zimbabwe  ZWE  2012
# 6152     Zimbabwe  ZWE  2013
# 6153     Zimbabwe  ZWE  2014
# 6154     Zimbabwe  ZWE  2015
# 6155     Zimbabwe  ZWE  2016
#
#       Prevalence - Alcohol and substance use disorders: Both (age-standardized percent) (%)
# 0                                              1.530549
# 1                                              1.530105
# 2                                              1.529283
# 3                                              1.530944
# 4                                              1.532076
# ...                                                 ...
# 6151                                           2.300518
# 6152                                           2.306298
# 6153                                           2.311257
# ...

# %%
#df2.rename(columns={'Prevalence - Alcohol and substance use disorders: Both (age-standardized percent) (%)':'Drug use disoder%'}, inplace=True)
#df2.drop(columns = {'Code'}, inplace=True)
df2
# Out:
#            Entity  Year  Drug use disoder%
# 0     Afghanistan  1990           1.530549
# 1     Afghanistan  1991           1.530105
# 2     Afghanistan  1992           1.529283
# 3     Afghanistan  1993           1.530944
# 4     Afghanistan  1994           1.532076
# ...           ...   ...                ...
# 6151     Zimbabwe  2012           2.300518
# 6152     Zimbabwe  2013           2.306298
# 6153     Zimbabwe  2014           2.311257
# 6154     Zimbabwe  2015           2.315047
# 6155     Zimbabwe  2016           2.320384
#
# [6156 rows x 3 columns]

# %%
df2.Year.value_counts()
# Out:
# 1990    228
# 2004    228
# 2015    228
# 2014    228
# 2013    228
# 2012    228
# 2011    228
# 2010    228
# 2009    228
# 2008    228
# 2007    228
# 2006    228
# 2005    228
# 2003    228
# 1991    228
# 2002    228
# 2001    228
# 2000    228
# 1999    228
# 1998    228
# 1997    228
# 1996    228
# 1995    228
# 1994    228
# 1993    228
# 1992    228
# 2016    228
# Name: Year, dtype: int64

# %%
data=df2[df2['Entity'] == 'North Korea']
data
data.plot(kind='line', x='Year', y = 'Drug use disoder%')
# Out:
# <AxesSubplot: xlabel='Year'>
