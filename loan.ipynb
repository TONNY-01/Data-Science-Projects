# %%
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
import pandas as pd
df = pd.read_csv(r'E:\ALL CSVs\Training Data.csv', index_col = False)
df.head(9)
# Out:
#    Id   Income  Age  Experience Married/Single House_Ownership Car_Ownership  \
# 0   1  1303834   23           3         single          rented            no
# 1   2  7574516   40          10         single          rented            no
# 2   3  3991815   66           4        married          rented            no
# 3   4  6256451   41           2         single          rented           yes
# 4   5  5768871   47          11         single          rented            no
# 5   6  6915937   64           0         single          rented            no
# 6   7  3954973   58          14        married          rented            no
# 7   8  1706172   33           2         single          rented            no
# 8   9  7566849   24          17         single          rented           yes
#
#             Profession                 CITY           STATE  CURRENT_JOB_YRS  \
# 0  Mechanical_engineer                 Rewa  Madhya_Pradesh                3
# ...

# %%
df['Married/Single'] = le.fit_transform(df['Married/Single'])

# %%
df['House_Ownership'] = le.fit_transform(df['House_Ownership'])
df['Car_Ownership'] = le.fit_transform(df['Car_Ownership'])
df['Profession'] = le.fit_transform(df['Profession'])
df['STATE'] = le.fit_transform(df['STATE'])
df['CITY'] = le.fit_transform(df['CITY'])

# %%
df
# Out:
#             Id   Income  Age  Experience  Married/Single  House_Ownership  \
# 0            1  1303834   23           3               1                2
# 1            2  7574516   40          10               1                2
# 2            3  3991815   66           4               0                2
# 3            4  6256451   41           2               1                2
# 4            5  5768871   47          11               1                2
# ...        ...      ...  ...         ...             ...              ...
# 251995  251996  8154883   43          13               1                2
# 251996  251997  2843572   26          10               1                2
# 251997  251998  4522448   46           7               1                2
# 251998  251999  6507128   45           0               1                2
# 251999  252000  9070230   70          17               1                2
#
#         Car_Ownership  Profession  CITY  STATE  CURRENT_JOB_YRS  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators = 1000, max_depth = 100)

# %%
X_train
# Out:
#          Income  Age  Experience  Marital_Status  House_Ownership  \
# 223480  1759916   33           0               1                0
# 177039  1325345   66           8               1                2
# 85476   3971141   67          16               1                2
# 243408  2252102   33           8               1                2
# 116275  3770663   53           5               1                2
# ...         ...  ...         ...             ...              ...
# 176963  9422918   77          11               1                2
# 117952  7716196   27           5               1                2
# 173685  2557871   55          14               1                2
# 43567   8914067   77          18               1                2
# 199340  6001312   70           4               1                2
#
#         Car_Ownership  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS
# 223480              0                0                 10
# ...

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=100, n_estimators=1000)

# %%
import numpy as np

# %%
input_data = (1759, 23, 0, 1, 1, 0, 1, 1)
data = np.asarray(input_data)
values = data.reshape(1, -1)
model.predict(values)
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
pred=model.predict(X_test)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
X_test.columns
# Out:
# Index(['Income', 'Age', 'Experience', 'Marital_Status', 'House_Ownership',
#        'Car_Ownership', 'CURRENT_JOB_YRS', 'CURRENT_HOUSE_YRS'],
#       dtype='object')

# %%
a = pd.DataFrame(pred)
a
# Out:
#        0
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
# ...   ..
# 50395  0
# 50396  0
# 50397  0
# 50398  0
# 50399  0
#
# [50400 rows x 1 columns]

# %%
import seaborn as sns

# %%
sns.scatterplot(x = pred, y=y_test)
# Out:
# <AxesSubplot: ylabel='Risk_Flag'>

# %%
df
# Out:
#             Id   Income  Age  Experience  Married/Single  House_Ownership  \
# 0            1  1303834   23           3               1                2
# 1            2  7574516   40          10               1                2
# 2            3  3991815   66           4               0                2
# 3            4  6256451   41           2               1                2
# 4            5  5768871   47          11               1                2
# ...        ...      ...  ...         ...             ...              ...
# 251995  251996  8154883   43          13               1                2
# 251996  251997  2843572   26          10               1                2
# 251997  251998  4522448   46           7               1                2
# 251998  251999  6507128   45           0               1                2
# 251999  252000  9070230   70          17               1                2
#
#         Car_Ownership  Profession  CITY  STATE  CURRENT_JOB_YRS  \
# ...

# %%
X = df[['Income', 'Age', 'Experience', 'Married/Single', 'House_Ownership', 'Car_Ownership', 'Profession', 'CITY', 'STATE', 'CURRENT_JOB_YRS', 'CURRENT_HOUSE_YRS']]

# %%
y = df.Risk_Flag

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)
X_train
# Out:
#          Income  Age  Experience  Marital_Status  House_Ownership  \
# 223480  1759916   33           0               1                0
# 177039  1325345   66           8               1                2
# 85476   3971141   67          16               1                2
# 243408  2252102   33           8               1                2
# 116275  3770663   53           5               1                2
# ...         ...  ...         ...             ...              ...
# 176963  9422918   77          11               1                2
# 117952  7716196   27           5               1                2
# 173685  2557871   55          14               1                2
# 43567   8914067   77          18               1                2
# 199340  6001312   70           4               1                2
#
#         Car_Ownership  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS
# 223480              0                0                 10
# ...

# %%
x=df.iloc[:,1:12]
x.drop(columns={'Profession', 'CITY', 'STATE'}, inplace=True)
x.rename(columns={'Married/Single':'Marital_Status'}, inplace=True)
x
# Out:
#          Income  Age  Experience  Marital_Status  House_Ownership  \
# 0       1303834   23           3               1                2
# 1       7574516   40          10               1                2
# 2       3991815   66           4               0                2
# 3       6256451   41           2               1                2
# 4       5768871   47          11               1                2
# ...         ...  ...         ...             ...              ...
# 251995  8154883   43          13               1                2
# 251996  2843572   26          10               1                2
# 251997  4522448   46           7               1                2
# 251998  6507128   45           0               1                2
# 251999  9070230   70          17               1                2
#
#         Car_Ownership  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS
# 0                   0                3                 13
# ...

# %%
df['CITY'].value_counts()
# Out:
# 312    1259
# 53     1208
# 64     1185
# 256    1180
# 313    1172
#        ...
# 304     486
# 315     459
# 41      457
# 152     448
# 147     431
# Name: CITY, Length: 317, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(pred, y_test)
accuracy
# Out:
# 0.8985714285714286

# %%
c = pd.read_csv(r"C:\Users\Admin\Desktop\Sample Prediction Dataset.csv", index_col = False)
c.drop(columns={'id'}, inplace=True)

# %%
a_train, a_test = train_test_split(c, test_size = 0.2)

# %%
a_test

# %%
len(c)

# %%
len(pred)

# %%
import pickle
with open('model_pickle','wb') as f:
    pickle.dump(model,f)

# %%
with open('model_pickle', 'rb') as f:
    mp = pickle.load(f)

# %%
input_data = (1759, 23, 0, 1, 1, 0, 1, 1)
data = np.asarray(input_data)
values = data.reshape(1, -1)
pre = mp.predict(values)
print(pre)
if (pre == [1]):
    print('This person is a fraud')
else:
    print('This person is not a fraud')
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# [1]
# This person is a fraud
